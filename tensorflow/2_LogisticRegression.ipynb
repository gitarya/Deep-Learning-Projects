# %%
import tensorflow as tf

# Import MINST data
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data", one_hot=True)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %%
# Parameters
learning_rate = 0.01
training_epochs = 25
batch_size = 100
display_step = 1

# tf Graph Input
x = tf.placeholder(tf.float32, [None, 784]) # mnist data image of shape 28*28=784
y = tf.placeholder(tf.float32, [None, 10]) # 0-9 digits recognition -> 10 classes

# Set model weights
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))

# construct model
pred = tf.nn.softmax(tf.matmul(x,W) + b) # softmax

# Minimize error using cross entropy
cost = tf.reduce_mean(-tf.reduce_sum(y*tf.log(pred), reduction_indices=1))
# Gradient Descent
optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost)

# Initialize with the variables (i.e assign their default value)
init = tf.global_variables_initializer()

# %%
# Start training
with tf.Session() as sess:
    sess.run(init)
    
    # Training cycle
    for epoch in range(training_epochs):
        avg_cost = 0.
        total_batch = int(mnist.train.num_examples/batch_size)
        # Loop over all batches
        for i in range(total_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            # Fit training using batch data
            _, c = sess.run([optimizer, cost], feed_dict={x: batch_xs,
                                                          y: batch_ys})
            
            # Compute average loss
            avg_cost += c/total_batch
        # Display logs per epoch ste
        if (epoch + 1) % display_step == 0:
            print("Epoch:", '%04d' % (epoch+1),'cost=',"{:.9f}".format(avg_cost))
            
        print("optimization Finished!")
        
        # Test model
        correct_prediction = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
        # Calculate accuracy for 3000 examples
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        print("Accuracy:", accuracy.eval({x: mnist.test.images[:3000],y:mnist.test.labels[:3000]}))
# Out:
# Epoch: 0001 cost= 1.183626915
# optimization Finished!
# Accuracy: 0.818
# Epoch: 0002 cost= 0.665265174
# optimization Finished!
# Accuracy: 0.843
# Epoch: 0003 cost= 0.552812753
# optimization Finished!
# Accuracy: 0.853
# Epoch: 0004 cost= 0.498610279
# optimization Finished!
# Accuracy: 0.855667
# Epoch: 0005 cost= 0.465480886
# optimization Finished!
# Accuracy: 0.860333
# Epoch: 0006 cost= 0.442564955
# optimization Finished!
# Accuracy: 0.864333
# Epoch: 0007 cost= 0.425557715
# optimization Finished!
# Accuracy: 0.869333
# Epoch: 0008 cost= 0.412209441
# optimization Finished!
# Accuracy: 0.870333
# Epoch: 0009 cost= 0.401406094
# optimization Finished!
# Accuracy: 0.872333
# Epoch: 0010 cost= 0.392436330
# optimization Finished!
# Accuracy: 0.872667
# Epoch: 0011 cost= 0.384777850
# optimization Finished!
# Accuracy: 0.876
# Epoch: 0012 cost= 0.378204954
# optimization Finished!
# Accuracy: 0.876333
# Epoch: 0013 cost= 0.372393829
# optimization Finished!
# Accuracy: 0.878333
# Epoch: 0014 cost= 0.367288059
# optimization Finished!
# Accuracy: 0.881
# Epoch: 0015 cost= 0.362743744
# optimization Finished!
# Accuracy: 0.881
# Epoch: 0016 cost= 0.358642759
# optimization Finished!
# Accuracy: 0.882
# Epoch: 0017 cost= 0.354884614
# optimization Finished!
# Accuracy: 0.883
# Epoch: 0018 cost= 0.351463080
# optimization Finished!
# Accuracy: 0.883
# Epoch: 0019 cost= 0.348291579
# optimization Finished!
# Accuracy: 0.882333
# Epoch: 0020 cost= 0.345463213
# optimization Finished!
# Accuracy: 0.887
# Epoch: 0021 cost= 0.342697027
# optimization Finished!
# Accuracy: 0.887
# Epoch: 0022 cost= 0.340230677
# optimization Finished!
# Accuracy: 0.886333
# Epoch: 0023 cost= 0.337916077
# optimization Finished!
# Accuracy: 0.889
# Epoch: 0024 cost= 0.335745806
# optimization Finished!
# Accuracy: 0.887333
# Epoch: 0025 cost= 0.333713714
# optimization Finished!
# Accuracy: 0.888333
